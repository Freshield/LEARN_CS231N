# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4 
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
  np.random.seed(0)
  return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
  np.random.seed(1)
  X = 10 * np.random.randn(num_inputs, input_size)
  y = np.array([0, 1, 2, 2, 1])
  return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print 'Your scores:'
print scores
print
print 'correct scores:'
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print correct_scores
print

# The difference should be very small. We get < 1e-7
print 'Difference between your scores and correct scores:'
print np.sum(np.abs(scores - correct_scores))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.68027204961e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.1)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print 'Difference between your loss and correct loss:'
print np.sum(np.abs(loss - correct_loss))
# Out:
# Difference between your loss and correct loss:
# 1.79856129989e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.1)

# these should all be less than 1e-8 or so
for param_name in grads:
  f = lambda W: net.loss(X, y, reg=0.1)[0]
  param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
  print '%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name]))
# Out:
# b2 max relative error: 3.865091e-11
# W2 max relative error: 3.440708e-09
# W1 max relative error: 3.561318e-09
# b1 max relative error: 1.555470e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=1e-5,
            num_iters=100, verbose=False)

print 'Final training loss: ', stats['loss_history'][-1]

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.0171496079387

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = range(num_training, num_training + num_validation)
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.5, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print 'Validation accuracy: ', val_acc
# Out:
# iteration 0 / 1000: loss 2.302954
# iteration 100 / 1000: loss 2.302550
# iteration 200 / 1000: loss 2.297648
# iteration 300 / 1000: loss 2.259602
# iteration 400 / 1000: loss 2.204170
# iteration 500 / 1000: loss 2.118565
# iteration 600 / 1000: loss 2.051535
# iteration 700 / 1000: loss 1.988466
# iteration 800 / 1000: loss 2.006591
# iteration 900 / 1000: loss 1.951473
# Validation accuracy:  0.287

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
  W1 = net.params['W1']
  W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
  plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
  plt.gca().axis('off')
  plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every 1% above 52% on the Test set we will award you with one extra bonus point. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
hidden_size = [x * 50 for x in range(1, 10, 1)]
learning_rate = [5e-5, 1e-4, 5e-4, 1e-3, 5e-3, 2e-3, 1e-2, 5e-2, 1e-1, 5e-1, 1]#
training_epoch = [x * 200 for x in range(1, 10, 1)]
regularization_strengths = [0.001, 0.002, 0.05, 0.07, 0.1, 0.2, 0.5, 1, 5, 10, 20]#
batch_size_choice = [20, 50, 100, 150, 200, 350, 400, 500, 600, 700, 1000]#

input_size = 32 * 32 * 3
num_classes = 10
learning_rate_decay=0.95

best_val = -1
best_stats = None
best_hype = {}

whole_time = len(hidden_size) * len(learning_rate) * len(training_epoch) * len(regularization_strengths) * len(batch_size_choice)
 
for bat_size in batch_size_choice:
    for reg_str in regularization_strengths:
        for train_circle in training_epoch:
            for lr_rate in learning_rate:
                for hid_size in hidden_size:
                    whole_time -= 1
                    
                    print
                    print "now rest times is:", whole_time
                    print "now hidden size is: ", hid_size
                    print "now learning rate is: ", lr_rate
                    print "now training epoch is:", train_circle
                    print "now regualrization streagths is: ", reg_str
                    print "now batch size is: ", bat_size
                    
                    net = TwoLayerNet(input_size, hid_size, num_classes)
                    
                    now_stats = net.train(X_train, y_train, X_val, y_val,
            learning_rate=lr_rate, learning_rate_decay=0.95,
            reg=reg_str, num_iters=train_circle,batch_size=bat_size, verbose=False)
                    
                    y_pred_val = net.predict(X_val)
                    acc_val = np.mean(y_pred_val == y_val)
                    
                    if acc_val > best_val:
                        best_val = acc_val
                        best_stats = now_stats
                        best_net = net
                        best_hype = {
                            'bat' : bat_size,
                            'reg' : reg_str,
                            'cir' : train_circle,
                            'ler' : lr_rate,
                            'hid' : hid_size,
                        }
                        
                        print "=============================================="
                        print "best accuray is:", best_val
                        print "best hidden size is: ", best_hype['hid']
                        print "best learning rate is: ", best_hype['ler']
                        print "best training epoch is:", best_hype['cir']
                        print "best regualrization streagths is: ", best_hype['reg']
                        print "best batch size is: ", best_hype['bat']
                        print "=============================================="
#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################

print "=============================================="
print "best accuray is:", best_val
print "best hidden size is: ", best_hype['hid']
print "best learning rate is: ", best_hype['ler']
print "best training epoch is:", best_hype['cir']
print "best regualrization streagths is: ", best_hype['reg']
print "best batch size is: ", best_hype['bat']
print "=============================================="
print
#自己加的(insert by myself)
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(best_stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(best_stats['train_acc_history'], label='train')
plt.plot(best_stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()
# Out:
# now rest times is: 107810
# now hidden size is:  50
# now learning rate is:  5e-05
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
# ==============================================
# best accuray is: 0.185
# best hidden size is:  50
# best learning rate is:  5e-05
# best training epoch is: 200
# best regualrization streagths is:  0.001
# best batch size is:  20
# ==============================================
#
# now rest times is: 107809
# now hidden size is:  100
# now learning rate is:  5e-05
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
# ==============================================
# best accuray is: 0.222
# best hidden size is:  100
# best learning rate is:  5e-05
# best training epoch is: 200
# best regualrization streagths is:  0.001
# best batch size is:  20
# ==============================================
#
# now rest times is: 107808
# now hidden size is:  150
# now learning rate is:  5e-05
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107807
# now hidden size is:  200
# now learning rate is:  5e-05
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107806
# now hidden size is:  250
# now learning rate is:  5e-05
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
# ==============================================
# best accuray is: 0.243
# best hidden size is:  250
# best learning rate is:  5e-05
# best training epoch is: 200
# best regualrization streagths is:  0.001
# best batch size is:  20
# ==============================================
#
# now rest times is: 107805
# now hidden size is:  300
# now learning rate is:  5e-05
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107804
# now hidden size is:  350
# now learning rate is:  5e-05
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
# ==============================================
# best accuray is: 0.257
# best hidden size is:  350
# best learning rate is:  5e-05
# best training epoch is: 200
# best regualrization streagths is:  0.001
# best batch size is:  20
# ==============================================
#
# now rest times is: 107803
# now hidden size is:  400
# now learning rate is:  5e-05
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
# ==============================================
# best accuray is: 0.263
# best hidden size is:  400
# best learning rate is:  5e-05
# best training epoch is: 200
# best regualrization streagths is:  0.001
# best batch size is:  20
# ==============================================
#
# now rest times is: 107802
# now hidden size is:  450
# now learning rate is:  5e-05
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107801
# now hidden size is:  50
# now learning rate is:  0.0001
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107800
# now hidden size is:  100
# now learning rate is:  0.0001
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107799
# now hidden size is:  150
# now learning rate is:  0.0001
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107798
# now hidden size is:  200
# now learning rate is:  0.0001
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107797
# now hidden size is:  250
# now learning rate is:  0.0001
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107796
# now hidden size is:  300
# now learning rate is:  0.0001
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107795
# now hidden size is:  350
# now learning rate is:  0.0001
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107794
# now hidden size is:  400
# now learning rate is:  0.0001
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107793
# now hidden size is:  450
# now learning rate is:  0.0001
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107792
# now hidden size is:  50
# now learning rate is:  0.0005
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
# ==============================================
# best accuray is: 0.282
# best hidden size is:  50
# best learning rate is:  0.0005
# best training epoch is: 200
# best regualrization streagths is:  0.001
# best batch size is:  20
# ==============================================
#
# now rest times is: 107791
# now hidden size is:  100
# now learning rate is:  0.0005
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
# ==============================================
# best accuray is: 0.29
# best hidden size is:  100
# best learning rate is:  0.0005
# best training epoch is: 200
# best regualrization streagths is:  0.001
# best batch size is:  20
# ==============================================
#
# now rest times is: 107790
# now hidden size is:  150
# now learning rate is:  0.0005
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107789
# now hidden size is:  200
# now learning rate is:  0.0005
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107788
# now hidden size is:  250
# now learning rate is:  0.0005
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
# ==============================================
# best accuray is: 0.299
# best hidden size is:  250
# best learning rate is:  0.0005
# best training epoch is: 200
# best regualrization streagths is:  0.001
# best batch size is:  20
# ==============================================
#
# now rest times is: 107787
# now hidden size is:  300
# now learning rate is:  0.0005
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
# ==============================================
# best accuray is: 0.305
# best hidden size is:  300
# best learning rate is:  0.0005
# best training epoch is: 200
# best regualrization streagths is:  0.001
# best batch size is:  20
# ==============================================
#
# now rest times is: 107786
# now hidden size is:  350
# now learning rate is:  0.0005
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107785
# now hidden size is:  400
# now learning rate is:  0.0005
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
# ==============================================
# best accuray is: 0.308
# best hidden size is:  400
# best learning rate is:  0.0005
# best training epoch is: 200
# best regualrization streagths is:  0.001
# best batch size is:  20
# ==============================================
#
# now rest times is: 107784
# now hidden size is:  450
# now learning rate is:  0.0005
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107783
# now hidden size is:  50
# now learning rate is:  0.001
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
# ==============================================
# best accuray is: 0.318
# best hidden size is:  50
# best learning rate is:  0.001
# best training epoch is: 200
# best regualrization streagths is:  0.001
# best batch size is:  20
# ==============================================
#
# now rest times is: 107782
# now hidden size is:  100
# now learning rate is:  0.001
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107781
# now hidden size is:  150
# now learning rate is:  0.001
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107780
# now hidden size is:  200
# now learning rate is:  0.001
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107779
# now hidden size is:  250
# now learning rate is:  0.001
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107778
# now hidden size is:  300
# now learning rate is:  0.001
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107777
# now hidden size is:  350
# now learning rate is:  0.001
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107776
# now hidden size is:  400
# now learning rate is:  0.001
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107775
# now hidden size is:  450
# now learning rate is:  0.001
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107774
# now hidden size is:  50
# now learning rate is:  0.005
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
# cs231n/classifiers/neural_net.py:104: RuntimeWarning: divide by zero encountered in log
#   data_loss = np.sum(-np.log(correct_class_scores)) / N
# now rest times is: 107773
# now hidden size is:  100
# now learning rate is:  0.005
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107772
# now hidden size is:  150
# now learning rate is:  0.005
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107771
# now hidden size is:  200
# now learning rate is:  0.005
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107770
# now hidden size is:  250
# now learning rate is:  0.005
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107769
# now hidden size is:  300
# now learning rate is:  0.005
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107768
# now hidden size is:  350
# now learning rate is:  0.005
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107767
# now hidden size is:  400
# now learning rate is:  0.005
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107766
# now hidden size is:  450
# now learning rate is:  0.005
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107765
# now hidden size is:  50
# now learning rate is:  0.002
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107764
# now hidden size is:  100
# now learning rate is:  0.002
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107763
# now hidden size is:  150
# now learning rate is:  0.002
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107762
# now hidden size is:  200
# now learning rate is:  0.002
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107761
# now hidden size is:  250
# now learning rate is:  0.002
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107760
# now hidden size is:  300
# now learning rate is:  0.002
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107759
# now hidden size is:  350
# now learning rate is:  0.002
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107758
# now hidden size is:  400
# now learning rate is:  0.002
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107757
# now hidden size is:  450
# now learning rate is:  0.002
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107756
# now hidden size is:  50
# now learning rate is:  0.01
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107755
# now hidden size is:  100
# now learning rate is:  0.01
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107754
# now hidden size is:  150
# now learning rate is:  0.01
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107753
# now hidden size is:  200
# now learning rate is:  0.01
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107752
# now hidden size is:  250
# now learning rate is:  0.01
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107751
# now hidden size is:  300
# now learning rate is:  0.01
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107750
# now hidden size is:  350
# now learning rate is:  0.01
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107749
# now hidden size is:  400
# now learning rate is:  0.01
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107748
# now hidden size is:  450
# now learning rate is:  0.01
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107747
# now hidden size is:  50
# now learning rate is:  0.05
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
# cs231n/classifiers/neural_net.py:99: RuntimeWarning: overflow encountered in subtract
#   scores -= np.max(scores, axis=1, keepdims=True)
# cs231n/classifiers/neural_net.py:99: RuntimeWarning: invalid value encountered in subtract
#   scores -= np.max(scores, axis=1, keepdims=True)
# cs231n/classifiers/neural_net.py:127: RuntimeWarning: invalid value encountered in less_equal
#   dhidden[hidden <= 0] = 0
# now rest times is: 107746
# now hidden size is:  100
# now learning rate is:  0.05
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
# cs231n/classifiers/neural_net.py:105: RuntimeWarning: overflow encountered in multiply
#   reg_loss = 0.5 * reg * np.sum(W1 * W1) + 0.5 * reg * np.sum(W2 * W2)
# now rest times is: 107745
# now hidden size is:  150
# now learning rate is:  0.05
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107744
# now hidden size is:  200
# now learning rate is:  0.05
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107743
# now hidden size is:  250
# now learning rate is:  0.05
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107742
# now hidden size is:  300
# now learning rate is:  0.05
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107741
# now hidden size is:  350
# now learning rate is:  0.05
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107740
# now hidden size is:  400
# now learning rate is:  0.05
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107739
# now hidden size is:  450
# now learning rate is:  0.05
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107738
# now hidden size is:  50
# now learning rate is:  0.1
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107737
# now hidden size is:  100
# now learning rate is:  0.1
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107736
# now hidden size is:  150
# now learning rate is:  0.1
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107735
# now hidden size is:  200
# now learning rate is:  0.1
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107734
# now hidden size is:  250
# now learning rate is:  0.1
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107733
# now hidden size is:  300
# now learning rate is:  0.1
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107732
# now hidden size is:  350
# now learning rate is:  0.1
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107731
# now hidden size is:  400
# now learning rate is:  0.1
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107730
# now hidden size is:  450
# now learning rate is:  0.1
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107729
# now hidden size is:  50
# now learning rate is:  0.5
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107728
# now hidden size is:  100
# now learning rate is:  0.5
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107727
# now hidden size is:  150
# now learning rate is:  0.5
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107726
# now hidden size is:  200
# now learning rate is:  0.5
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107725
# now hidden size is:  250
# now learning rate is:  0.5
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107724
# now hidden size is:  300
# now learning rate is:  0.5
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107723
# now hidden size is:  350
# now learning rate is:  0.5
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107722
# now hidden size is:  400
# now learning rate is:  0.5
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107721
# now hidden size is:  450
# now learning rate is:  0.5
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107720
# now hidden size is:  50
# now learning rate is:  1
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107719
# now hidden size is:  100
# now learning rate is:  1
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107718
# now hidden size is:  150
# now learning rate is:  1
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107717
# now hidden size is:  200
# now learning rate is:  1
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107716
# now hidden size is:  250
# now learning rate is:  1
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107715
# now hidden size is:  300
# now learning rate is:  1
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107714
# now hidden size is:  350
# now learning rate is:  1
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107713
# now hidden size is:  400
# now learning rate is:  1
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107712
# now hidden size is:  450
# now learning rate is:  1
# now training epoch is: 200
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107711
# now hidden size is:  50
# now learning rate is:  5e-05
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107710
# now hidden size is:  100
# now learning rate is:  5e-05
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107709
# now hidden size is:  150
# now learning rate is:  5e-05
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107708
# now hidden size is:  200
# now learning rate is:  5e-05
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107707
# now hidden size is:  250
# now learning rate is:  5e-05
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107706
# now hidden size is:  300
# now learning rate is:  5e-05
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107705
# now hidden size is:  350
# now learning rate is:  5e-05
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107704
# now hidden size is:  400
# now learning rate is:  5e-05
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107703
# now hidden size is:  450
# now learning rate is:  5e-05
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107702
# now hidden size is:  50
# now learning rate is:  0.0001
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107701
# now hidden size is:  100
# now learning rate is:  0.0001
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107700
# now hidden size is:  150
# now learning rate is:  0.0001
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107699
# now hidden size is:  200
# now learning rate is:  0.0001
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107698
# now hidden size is:  250
# now learning rate is:  0.0001
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107697
# now hidden size is:  300
# now learning rate is:  0.0001
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107696
# now hidden size is:  350
# now learning rate is:  0.0001
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107695
# now hidden size is:  400
# now learning rate is:  0.0001
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107694
# now hidden size is:  450
# now learning rate is:  0.0001
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107693
# now hidden size is:  50
# now learning rate is:  0.0005
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
# ==============================================
# best accuray is: 0.361
# best hidden size is:  50
# best learning rate is:  0.0005
# best training epoch is: 400
# best regualrization streagths is:  0.001
# best batch size is:  20
# ==============================================
#
# now rest times is: 107692
# now hidden size is:  100
# now learning rate is:  0.0005
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107691
# now hidden size is:  150
# now learning rate is:  0.0005
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107690
# now hidden size is:  200
# now learning rate is:  0.0005
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
# ==============================================
# best accuray is: 0.373
# best hidden size is:  200
# best learning rate is:  0.0005
# best training epoch is: 400
# best regualrization streagths is:  0.001
# best batch size is:  20
# ==============================================
#
# now rest times is: 107689
# now hidden size is:  250
# now learning rate is:  0.0005
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107688
# now hidden size is:  300
# now learning rate is:  0.0005
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107687
# now hidden size is:  350
# now learning rate is:  0.0005
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107686
# now hidden size is:  400
# now learning rate is:  0.0005
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107685
# now hidden size is:  450
# now learning rate is:  0.0005
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107684
# now hidden size is:  50
# now learning rate is:  0.001
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107683
# now hidden size is:  100
# now learning rate is:  0.001
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107682
# now hidden size is:  150
# now learning rate is:  0.001
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107681
# now hidden size is:  200
# now learning rate is:  0.001
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107680
# now hidden size is:  250
# now learning rate is:  0.001
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107679
# now hidden size is:  300
# now learning rate is:  0.001
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107678
# now hidden size is:  350
# now learning rate is:  0.001
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107677
# now hidden size is:  400
# now learning rate is:  0.001
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107676
# now hidden size is:  450
# now learning rate is:  0.001
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107675
# now hidden size is:  50
# now learning rate is:  0.005
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107674
# now hidden size is:  100
# now learning rate is:  0.005
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107673
# now hidden size is:  150
# now learning rate is:  0.005
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107672
# now hidden size is:  200
# now learning rate is:  0.005
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107671
# now hidden size is:  250
# now learning rate is:  0.005
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107670
# now hidden size is:  300
# now learning rate is:  0.005
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107669
# now hidden size is:  350
# now learning rate is:  0.005
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107668
# now hidden size is:  400
# now learning rate is:  0.005
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107667
# now hidden size is:  450
# now learning rate is:  0.005
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107666
# now hidden size is:  50
# now learning rate is:  0.002
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107665
# now hidden size is:  100
# now learning rate is:  0.002
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107664
# now hidden size is:  150
# now learning rate is:  0.002
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107663
# now hidden size is:  200
# now learning rate is:  0.002
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107662
# now hidden size is:  250
# now learning rate is:  0.002
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107661
# now hidden size is:  300
# now learning rate is:  0.002
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107660
# now hidden size is:  350
# now learning rate is:  0.002
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107659
# now hidden size is:  400
# now learning rate is:  0.002
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107658
# now hidden size is:  450
# now learning rate is:  0.002
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107657
# now hidden size is:  50
# now learning rate is:  0.01
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107656
# now hidden size is:  100
# now learning rate is:  0.01
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107655
# now hidden size is:  150
# now learning rate is:  0.01
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107654
# now hidden size is:  200
# now learning rate is:  0.01
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107653
# now hidden size is:  250
# now learning rate is:  0.01
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107652
# now hidden size is:  300
# now learning rate is:  0.01
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107651
# now hidden size is:  350
# now learning rate is:  0.01
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107650
# now hidden size is:  400
# now learning rate is:  0.01
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107649
# now hidden size is:  450
# now learning rate is:  0.01
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107648
# now hidden size is:  50
# now learning rate is:  0.05
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107647
# now hidden size is:  100
# now learning rate is:  0.05
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107646
# now hidden size is:  150
# now learning rate is:  0.05
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107645
# now hidden size is:  200
# now learning rate is:  0.05
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107644
# now hidden size is:  250
# now learning rate is:  0.05
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107643
# now hidden size is:  300
# now learning rate is:  0.05
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107642
# now hidden size is:  350
# now learning rate is:  0.05
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107641
# now hidden size is:  400
# now learning rate is:  0.05
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107640
# now hidden size is:  450
# now learning rate is:  0.05
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107639
# now hidden size is:  50
# now learning rate is:  0.1
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107638
# now hidden size is:  100
# now learning rate is:  0.1
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107637
# now hidden size is:  150
# now learning rate is:  0.1
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107636
# now hidden size is:  200
# now learning rate is:  0.1
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107635
# now hidden size is:  250
# now learning rate is:  0.1
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107634
# now hidden size is:  300
# now learning rate is:  0.1
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107633
# now hidden size is:  350
# now learning rate is:  0.1
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107632
# now hidden size is:  400
# now learning rate is:  0.1
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107631
# now hidden size is:  450
# now learning rate is:  0.1
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107630
# now hidden size is:  50
# now learning rate is:  0.5
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107629
# now hidden size is:  100
# now learning rate is:  0.5
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107628
# now hidden size is:  150
# now learning rate is:  0.5
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107627
# now hidden size is:  200
# now learning rate is:  0.5
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107626
# now hidden size is:  250
# now learning rate is:  0.5
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107625
# now hidden size is:  300
# now learning rate is:  0.5
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107624
# now hidden size is:  350
# now learning rate is:  0.5
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107623
# now hidden size is:  400
# now learning rate is:  0.5
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107622
# now hidden size is:  450
# now learning rate is:  0.5
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107621
# now hidden size is:  50
# now learning rate is:  1
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107620
# now hidden size is:  100
# now learning rate is:  1
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107619
# now hidden size is:  150
# now learning rate is:  1
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107618
# now hidden size is:  200
# now learning rate is:  1
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107617
# now hidden size is:  250
# now learning rate is:  1
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107616
# now hidden size is:  300
# now learning rate is:  1
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107615
# now hidden size is:  350
# now learning rate is:  1
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107614
# now hidden size is:  400
# now learning rate is:  1
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107613
# now hidden size is:  450
# now learning rate is:  1
# now training epoch is: 400
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107612
# now hidden size is:  50
# now learning rate is:  5e-05
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107611
# now hidden size is:  100
# now learning rate is:  5e-05
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107610
# now hidden size is:  150
# now learning rate is:  5e-05
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107609
# now hidden size is:  200
# now learning rate is:  5e-05
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107608
# now hidden size is:  250
# now learning rate is:  5e-05
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107607
# now hidden size is:  300
# now learning rate is:  5e-05
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107606
# now hidden size is:  350
# now learning rate is:  5e-05
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107605
# now hidden size is:  400
# now learning rate is:  5e-05
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107604
# now hidden size is:  450
# now learning rate is:  5e-05
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107603
# now hidden size is:  50
# now learning rate is:  0.0001
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107602
# now hidden size is:  100
# now learning rate is:  0.0001
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107601
# now hidden size is:  150
# now learning rate is:  0.0001
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107600
# now hidden size is:  200
# now learning rate is:  0.0001
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107599
# now hidden size is:  250
# now learning rate is:  0.0001
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107598
# now hidden size is:  300
# now learning rate is:  0.0001
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107597
# now hidden size is:  350
# now learning rate is:  0.0001
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107596
# now hidden size is:  400
# now learning rate is:  0.0001
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107595
# now hidden size is:  450
# now learning rate is:  0.0001
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107594
# now hidden size is:  50
# now learning rate is:  0.0005
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107593
# now hidden size is:  100
# now learning rate is:  0.0005
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107592
# now hidden size is:  150
# now learning rate is:  0.0005
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
# ==============================================
# best accuray is: 0.387
# best hidden size is:  150
# best learning rate is:  0.0005
# best training epoch is: 600
# best regualrization streagths is:  0.001
# best batch size is:  20
# ==============================================
#
# now rest times is: 107591
# now hidden size is:  200
# now learning rate is:  0.0005
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107590
# now hidden size is:  250
# now learning rate is:  0.0005
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
# ==============================================
# best accuray is: 0.392
# best hidden size is:  250
# best learning rate is:  0.0005
# best training epoch is: 600
# best regualrization streagths is:  0.001
# best batch size is:  20
# ==============================================
#
# now rest times is: 107589
# now hidden size is:  300
# now learning rate is:  0.0005
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107588
# now hidden size is:  350
# now learning rate is:  0.0005
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107587
# now hidden size is:  400
# now learning rate is:  0.0005
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107586
# now hidden size is:  450
# now learning rate is:  0.0005
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
# ==============================================
# best accuray is: 0.395
# best hidden size is:  450
# best learning rate is:  0.0005
# best training epoch is: 600
# best regualrization streagths is:  0.001
# best batch size is:  20
# ==============================================
#
# now rest times is: 107585
# now hidden size is:  50
# now learning rate is:  0.001
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107584
# now hidden size is:  100
# now learning rate is:  0.001
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107583
# now hidden size is:  150
# now learning rate is:  0.001
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107582
# now hidden size is:  200
# now learning rate is:  0.001
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107581
# now hidden size is:  250
# now learning rate is:  0.001
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107580
# now hidden size is:  300
# now learning rate is:  0.001
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107579
# now hidden size is:  350
# now learning rate is:  0.001
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107578
# now hidden size is:  400
# now learning rate is:  0.001
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107577
# now hidden size is:  450
# now learning rate is:  0.001
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107576
# now hidden size is:  50
# now learning rate is:  0.005
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107575
# now hidden size is:  100
# now learning rate is:  0.005
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107574
# now hidden size is:  150
# now learning rate is:  0.005
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107573
# now hidden size is:  200
# now learning rate is:  0.005
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107572
# now hidden size is:  250
# now learning rate is:  0.005
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107571
# now hidden size is:  300
# now learning rate is:  0.005
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107570
# now hidden size is:  350
# now learning rate is:  0.005
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107569
# now hidden size is:  400
# now learning rate is:  0.005
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107568
# now hidden size is:  450
# now learning rate is:  0.005
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107567
# now hidden size is:  50
# now learning rate is:  0.002
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107566
# now hidden size is:  100
# now learning rate is:  0.002
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107565
# now hidden size is:  150
# now learning rate is:  0.002
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107564
# now hidden size is:  200
# now learning rate is:  0.002
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107563
# now hidden size is:  250
# now learning rate is:  0.002
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107562
# now hidden size is:  300
# now learning rate is:  0.002
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107561
# now hidden size is:  350
# now learning rate is:  0.002
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107560
# now hidden size is:  400
# now learning rate is:  0.002
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107559
# now hidden size is:  450
# now learning rate is:  0.002
# now training epoch is: 600
# now regualrization streagths is:  0.001
# now batch size is:  20
#
# now rest times is: 107558
# now hidden size is:  50
# now learning rate is:  0.01
# ...
# now learning rate is:  0.0001
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100073
# now hidden size is:  350
# now learning rate is:  0.0001
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100072
# now hidden size is:  400
# now learning rate is:  0.0001
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100071
# now hidden size is:  450
# now learning rate is:  0.0001
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100070
# now hidden size is:  50
# now learning rate is:  0.0005
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100069
# now hidden size is:  100
# now learning rate is:  0.0005
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100068
# now hidden size is:  150
# now learning rate is:  0.0005
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100067
# now hidden size is:  200
# now learning rate is:  0.0005
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100066
# now hidden size is:  250
# now learning rate is:  0.0005
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100065
# now hidden size is:  300
# now learning rate is:  0.0005
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100064
# now hidden size is:  350
# now learning rate is:  0.0005
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100063
# now hidden size is:  400
# now learning rate is:  0.0005
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100062
# now hidden size is:  450
# now learning rate is:  0.0005
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100061
# now hidden size is:  50
# now learning rate is:  0.001
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100060
# now hidden size is:  100
# now learning rate is:  0.001
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100059
# now hidden size is:  150
# now learning rate is:  0.001
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100058
# now hidden size is:  200
# now learning rate is:  0.001
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100057
# now hidden size is:  250
# now learning rate is:  0.001
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100056
# now hidden size is:  300
# now learning rate is:  0.001
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100055
# now hidden size is:  350
# now learning rate is:  0.001
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100054
# now hidden size is:  400
# now learning rate is:  0.001
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100053
# now hidden size is:  450
# now learning rate is:  0.001
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100052
# now hidden size is:  50
# now learning rate is:  0.005
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100051
# now hidden size is:  100
# now learning rate is:  0.005
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100050
# now hidden size is:  150
# now learning rate is:  0.005
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100049
# now hidden size is:  200
# now learning rate is:  0.005
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100048
# now hidden size is:  250
# now learning rate is:  0.005
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100047
# now hidden size is:  300
# now learning rate is:  0.005
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100046
# now hidden size is:  350
# now learning rate is:  0.005
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100045
# now hidden size is:  400
# now learning rate is:  0.005
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100044
# now hidden size is:  450
# now learning rate is:  0.005
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100043
# now hidden size is:  50
# now learning rate is:  0.002
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100042
# now hidden size is:  100
# now learning rate is:  0.002
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100041
# now hidden size is:  150
# now learning rate is:  0.002
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100040
# now hidden size is:  200
# now learning rate is:  0.002
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100039
# now hidden size is:  250
# now learning rate is:  0.002
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100038
# now hidden size is:  300
# now learning rate is:  0.002
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100037
# now hidden size is:  350
# now learning rate is:  0.002
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100036
# now hidden size is:  400
# now learning rate is:  0.002
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100035
# now hidden size is:  450
# now learning rate is:  0.002
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100034
# now hidden size is:  50
# now learning rate is:  0.01
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100033
# now hidden size is:  100
# now learning rate is:  0.01
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100032
# now hidden size is:  150
# now learning rate is:  0.01
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100031
# now hidden size is:  200
# now learning rate is:  0.01
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100030
# now hidden size is:  250
# now learning rate is:  0.01
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100029
# now hidden size is:  300
# now learning rate is:  0.01
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100028
# now hidden size is:  350
# now learning rate is:  0.01
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100027
# now hidden size is:  400
# now learning rate is:  0.01
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100026
# now hidden size is:  450
# now learning rate is:  0.01
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100025
# now hidden size is:  50
# now learning rate is:  0.05
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100024
# now hidden size is:  100
# now learning rate is:  0.05
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100023
# now hidden size is:  150
# now learning rate is:  0.05
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100022
# now hidden size is:  200
# now learning rate is:  0.05
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100021
# now hidden size is:  250
# now learning rate is:  0.05
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100020
# now hidden size is:  300
# now learning rate is:  0.05
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100019
# now hidden size is:  350
# now learning rate is:  0.05
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100018
# now hidden size is:  400
# now learning rate is:  0.05
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100017
# now hidden size is:  450
# now learning rate is:  0.05
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100016
# now hidden size is:  50
# now learning rate is:  0.1
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100015
# now hidden size is:  100
# now learning rate is:  0.1
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100014
# now hidden size is:  150
# now learning rate is:  0.1
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100013
# now hidden size is:  200
# now learning rate is:  0.1
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100012
# now hidden size is:  250
# now learning rate is:  0.1
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100011
# now hidden size is:  300
# now learning rate is:  0.1
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100010
# now hidden size is:  350
# now learning rate is:  0.1
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100009
# now hidden size is:  400
# now learning rate is:  0.1
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100008
# now hidden size is:  450
# now learning rate is:  0.1
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100007
# now hidden size is:  50
# now learning rate is:  0.5
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100006
# now hidden size is:  100
# now learning rate is:  0.5
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100005
# now hidden size is:  150
# now learning rate is:  0.5
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100004
# now hidden size is:  200
# now learning rate is:  0.5
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100003
# now hidden size is:  250
# now learning rate is:  0.5
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100002
# now hidden size is:  300
# now learning rate is:  0.5
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100001
# now hidden size is:  350
# now learning rate is:  0.5
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 100000
# now hidden size is:  400
# now learning rate is:  0.5
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 99999
# now hidden size is:  450
# now learning rate is:  0.5
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 99998
# now hidden size is:  50
# now learning rate is:  1
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 99997
# now hidden size is:  100
# now learning rate is:  1
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 99996
# now hidden size is:  150
# now learning rate is:  1
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 99995
# now hidden size is:  200
# now learning rate is:  1
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 99994
# now hidden size is:  250
# now learning rate is:  1
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 99993
# now hidden size is:  300
# now learning rate is:  1
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 99992
# now hidden size is:  350
# now learning rate is:  1
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 99991
# now hidden size is:  400
# now learning rate is:  1
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
#
# now rest times is: 99990
# now hidden size is:  450
# now learning rate is:  1
# now training epoch is: 1400
# now regualrization streagths is:  5
# now batch size is:  20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-ff18829ce7e6> in <module>()
#      48                     now_stats = net.train(X_train, y_train, X_val, y_val,
#      49             learning_rate=lr_rate, learning_rate_decay=0.95,
# ---> 50             reg=reg_str, num_iters=train_circle,batch_size=bat_size, verbose=False)
#      51
#      52                     y_pred_val = net.predict(X_val)
#
# /media/freshield/BUFFER/LEARN_CS231N/assignment1/cs231n/classifiers/neural_net.pyc in train(self, X, y, X_val, y_val, learning_rate, learning_rate_decay, reg, num_iters, batch_size, verbose)
#     188
#     189       # Compute loss and gradients using the current minibatch
# --> 190       loss, grads = self.loss(X_batch, y=y_batch, reg=reg)
#     191       loss_history.append(loss)
#     192
#
# /media/freshield/BUFFER/LEARN_CS231N/assignment1/cs231n/classifiers/neural_net.pyc in loss(self, X, y, reg)
#     103     correct_class_scores = probs[range(N), y]
#     104     data_loss = np.sum(-np.log(correct_class_scores)) / N
# --> 105     reg_loss = 0.5 * reg * np.sum(W1 * W1) + 0.5 * reg * np.sum(W2 * W2)
#     106     loss = data_loss + reg_loss
#     107
#
# /opt/anaconda2/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in sum(a, axis, dtype, out, keepdims)
#    1846     else:
#    1847         return _methods._sum(a, axis=axis, dtype=dtype,
# -> 1848                             out=out, **kwargs)
#    1849
#    1850
#
# /opt/anaconda2/lib/python2.7/site-packages/numpy/core/_methods.pyc in _sum(a, axis, dtype, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#      34 def _prod(a, axis=None, dtype=None, out=None, keepdims=False):
#
# KeyboardInterrupt:

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print 'Test accuracy: ', test_acc
# Out:
# Test accuracy:  0.444
